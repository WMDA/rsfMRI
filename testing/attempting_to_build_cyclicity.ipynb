# %% [markdown]
# # Cyclicity
#
# ## Cyclic v periodic.
# All periodic process are cyclic (go in cyclics) but not vice versa.
# Non periodic cyclic processes have no time interval (P) such that a shift along the time axis by P leaves it invariant

# %% [markdown]
# ## Uncovering periodicity in time series
# Any cyclic phenomenon, that is one whose underlying state space is a circle:
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">C</mi>
#   </mrow>
#   <mo>&#x2245;<!-- ≅ --></mo>
#   <msup>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="double-struck">S</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msup>
# </math>
# can be turned into a periodoc phenomenon on the state of space
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="sans-serif">T</mi>
#   </mrow>
#   <mo>&#x2245;<!-- ≅ --></mo>
#   <msup>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="double-struck">R</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msup>
# </math>
# which is the natural covering of C.
#
# The domain and range of the mapping <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="fraktur">J</mi>
#   </mrow>
#   <mo>:</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">T</mi>
#   </mrow>
#   <mo stretchy="false">&#x2192;<!-- → --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">C</mi>
#   </mrow>
# </math> can be parameterized in a consistent so that two points T serperated by period (P) can be mapped to the same point of C.
#
# So a circle can be represented as <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">C</mi>
#   </mrow>
#   <mo>&#x2245;<!-- ≅ --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="double-struck">R</mi>
#   </mrow>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mo>/</mo>
#   </mrow>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">P</mi>
#   </mrow>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="double-struck">Z</mi>
#   </mrow>
# </math>
#
# So any process that traverses a cycle can be made periodic by changing the co-ordiantes on the T.
#
# The parameteization of C is called the internal clock. The consistent parameterization of T is called the internal time and reserving for points of C is called internal state.

# %% [markdown]
# All the stuff above for periodicity is absent in cases of non period cyclic processes.
#
# Take an arbitrary parameterization of the internal clock: <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold"> R : </mi>
#   </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold"> R</mi>
#   </mrow>
#   <mo stretchy="false">&#x2192;<!-- → --></mo>
#   <msup>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="double-struck">T</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msup>
# </math>
#
# A P-period function is <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">f</mi>
#   </mrow>
#   <mo>:</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">T</mi>
#   </mrow>
#   <mo stretchy="false">&#x2192;<!-- → --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">V</mi>
#   </mrow>
# </math> with some values in the range V. <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">f</mi>
#   </mrow>
#   <mo>:</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">C</mi>
#   </mrow>
#   <mo stretchy="false">&#x2192;<!-- → --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">V</mi>
#   </mrow>
# </math> then defines the internal space
#
#
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi class="MJX-tex-caligraphic" mathvariant="script">R</mi>
#   </mrow>
#   <mo>:</mo>
#   <mi>&#x03C4;<!-- τ --></mi>
#   <mo stretchy="false">&#x21A6;<!-- ↦ --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">f</mi>
#   </mrow>
#   <mo stretchy="false">(</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">R</mi>
#   </mrow>
#   <mo stretchy="false">(</mo>
#   <mi>&#x03C4;<!-- τ --></mi>
#   <mo stretchy="false">)</mo>
#   <mo stretchy="false">)</mo>
#   <mo>&#x2208;<!-- ∈ --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">V</mi>
#   </mrow>
# </math> defines a vector valued function with the values being the state of a cyclic phenomenon observed at time t
#
# A way to recover the underlying periodic function f on the internal clock f o R is to idenitfy the values taken by observations and recovering the internal space. We could identify a specrial value of f o R such as the critical linear function, but this is very susceptible to disruptions by noise
#
# We we will assume the range of the observed process is a d-dimensional euclidean space: <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi class="MJX-tex-caligraphic" mathvariant="script">V</mi>
#   </mrow>
#   <mo>&#x2245;<!-- ≅ --></mo>
#   <msup>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="double-struck">R</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">d</mi>
#       </mrow>
#     </mrow>
#   </msup>
# </math> with co-ordinates <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>&#x03C7;<!-- χ --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="fraktur">j</mi>
#       </mrow>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="fraktur">j</mi>
#   </mrow>
#   <mo>=</mo>
#   <mn>1</mn>
#   <mo>,</mo>
#   <mo>&#x2026;<!-- … --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">d</mi>
#   </mrow>
# </math>

# %% [markdown]
# ## Trajectories and Invariants
#
# How do we reparametrizate invariant functionals of trajectories.
#
# Iterated integrals are explicitly reparamatrization invariant of a trajectory γ and defined in an inductive fashion. Iterated integration is the process of repeatedly integrating the results of previous integrations. Iterated intergrals of order zero are constants, associating to any trajectory γ a number <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">I</mi>
#   </mrow>
#   <mo stretchy="false">(</mo>
#   <mi>&#x03B3;<!-- γ --></mi>
#   <mo stretchy="false">)</mo>
#   <mo>&#x2261;<!-- ≡ --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">c</mi>
#   </mrow>
#   <mo>&#x2208;<!-- ∈ --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="double-struck">R</mi>
#   </mrow>
# </math> . For k > 0 the iterated integrals of order k are defined as the vector space generated by the functionals:
#
# \begin{equation*}\mathrm{I} (\gamma):=\sum\limits_{1\leqslant \mathfrak{j}\leqslant \mathrm{d}}\int_{\mathrm{t}_{\mathrm{s}}}^{\mathrm{t}_{\mathrm{f}}}\mathrm{I}_{\mathrm{j}}(\gamma_{\mathrm{t}_{\mathrm{s}},\mathrm{t}})\mathrm{d}\gamma_{\mathrm{j}}(\mathrm{t}),
# \end{equation*}
#
# Ij are the iterated integrals of order < k.
#
#
# ### Different orders
#
# Orders decribe the order in which multiple integrals are evaluated.
#
# Order 1: the invariants of order 1 are exactly the increments of the trajectory over the interval I (basically just dxdy)
# Order 2: renders more information than mere increments. Defined as:
# \begin{equation*}
# \mathrm{I}_{\mathrm{k},\mathrm{l}}=\int_{\mathrm{t}_{\mathrm{s}}}^{\mathrm{t}_{\mathrm{f}}}\gamma_{\mathrm{k}}(\mathrm{t})\mathrm{d}\gamma_{\mathrm{l}}(\mathrm{t}).
# \end{equation*}
#
# and forms a vector space spanned by the alebraic areas encompassed by the projections of the trajectory γ onto various co-ordinate 2-planes (γ might need to be closed up by adding a striaght segment connecting the start and end point of the resultant line)
#
# ### Completeness of Iterated integrals.
# Iterated integrals are invariant with respect to a reparameterization. Parallel translation <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>&#x03B3;<!-- γ --></mi>
#   <mo stretchy="false">&#x21A6;<!-- ↦ --></mo>
#   <mi>&#x03B3;<!-- γ --></mi>
#   <mo>+</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">c</mi>
#   </mrow>
#   <mo>,</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">c</mi>
#   </mrow>
#   <mo>&#x2208;<!-- ∈ --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">V</mi>
#   </mrow>
# </math> leaves the iterated integrals invariant.
#
# A detour is a segement of trajectory γ that is backtracked immediately and represents a concatention
#
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>&#x03B3;<!-- γ --></mi>
#   <mo>=</mo>
#   <msub>
#     <mi>&#x03B3;<!-- γ --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msub>
#   <mo fence="false" stretchy="false">|</mo>
#   <msub>
#     <mi>&#x03B3;<!-- γ --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>2</mn>
#     </mrow>
#   </msub>
#   <mo fence="false" stretchy="false">|</mo>
#   <msubsup>
#     <mi>&#x03B3;<!-- γ --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>2</mn>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mo>&#x2212;<!-- − --></mo>
#       <mn>1</mn>
#     </mrow>
#   </msubsup>
#   <mo fence="false" stretchy="false">|</mo>
#   <msub>
#     <mi>&#x03B3;<!-- γ --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>3</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
# </math>
# where | means concatenation of the trajectories so that the endpoint of one corresponds to the starting point of the other. γ-1 is the trajectory γ backwards.
# So γ2|γ2-1 is a detour.
#
# Removing a detour does not change any of the iterated integrals. So a trajectory without detours is irreducible and a trajectory with a range in dimension > 1 makes it irreducible. An irreducible trajectory with values R1 is just a monotone function: the theory of iterated integrals relies on the multivariate character of the signals.
#
# Iterated path integrals form a full system of the invariants of irreducible trajectories (defined up to reparameterization) in Euclidean space, up to a translation of the curve. Two irreducibel trajectories <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <msub>
#     <mi>&#x03B3;<!-- γ --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <msub>
#     <mi>&#x03B3;<!-- γ --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>2</mn>
#     </mrow>
#   </msub>
#   <mo>:</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">I</mi>
#   </mrow>
#   <mo stretchy="false">&#x2192;<!-- → --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">V</mi>
#   </mrow>
# </math>
# are equal up to translation and reparameterization if and only if all their corresponding iterated integrals coincide. So an irreducible trajectory is characterized by its iterated integrals, which for a complete system of it (reparameterization invariant) parameters.

# %% [markdown]
# ## Leaders and follwers
#
# Any data driven exploration of parameterization-independent features can rely on completeness of the sytems functionals. THis can then be applied to try and undercover cyclic phenomena.
#
# A key detail for this, is that cyclic phnomena is self-sustained cyclicing, where ane active process triggers another one etc (think one neuron firing to another one etc). So if one effect preceds another the oriented area on the parameteric joint plot of the corresponding functions will surround a positive algebraic area. This assumes that k = 1, if not then the lead-follow relationship flips.
#
# - Oriented area is the surface area with a specified orientation (either positive to indicate going up, negative to indicate going down etc)
# - A parametric plot is one in which a function or expression is plotted against another function or expression that uses the same independent variable
#
# ### Lead matrix when trajectory γ is closed
#
# \begin{equation*}
# \mathrm{A}_{\text{kl}}:=\frac{1}{2}\int_{\mathrm{t}}\gamma_{\mathrm{l}}\mathrm{d}\gamma_{\mathrm{k}}-\gamma_{\mathrm{k}}\mathrm{d}\gamma_{l}.
# \end{equation*}
#
# THe integrals are equal to the oriented areas of the two-dimensional projections of the trajectory γ on the co-ordinate planes.
#
# The lead matrix:
#
# \begin{equation*}
# \mathrm{A}=(\mathrm{A}_{\text{kl}})_{1\leqslant \mathrm{k},\mathrm{l}\leqslant \mathrm{d}}
# \end{equation*}
#
# with the intepretion that an element Akl is poisitive if l follows k
#
# ### Lead matrix with noisey data
#
# \begin{equation*}
# \gamma^{\epsilon}(\tau)=\gamma(\tau)+\epsilon(\tau),
# \end{equation*}
#
# where <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">f</mi>
#   </mrow>
#   <mo>:</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="bold">C</mi>
#   </mrow>
#   <mo stretchy="false">&#x2192;<!-- → --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">V</mi>
#   </mrow>
# </math> is a cyclic observation, R is the internal clock parametrization, <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>&#x03B3;<!-- γ --></mi>
#   <mo stretchy="false">(</mo>
#   <mi>&#x03C4;<!-- τ --></mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">f</mi>
#   </mrow>
#   <mo stretchy="false">(</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">R</mi>
#   </mrow>
#   <mo stretchy="false">(</mo>
#   <mi>&#x03C4;<!-- τ --></mi>
#   <mo stretchy="false">)</mo>
#   <mo stretchy="false">)</mo>
# </math> and <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>&#x03F5;<!-- ϵ --></mi>
#   <mo>:</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="double-struck">R</mi>
#   </mrow>
#   <mo stretchy="false">&#x2192;<!-- → --></mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">V</mi>
#   </mrow>
# </math> are noise
#
# We need to take into account multidimensional Brownian noise etc. So <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="fraktur">l</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="fraktur">l</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>2</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="fraktur">l</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>3</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <mo>&#x2026;<!-- … --></mo>
# </math> is a sequence of interval lengths such that:
# \begin{equation*}
# l_{\mathrm{k}}\rightarrow\infty;l_{\mathrm{k}}/\mathrm{L}_{\mathrm{k}}\rightarrow 0,\ \text{ask} \rightarrow\infty,
# \end{equation*}
#
# where <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="normal">L</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">k</mi>
#       </mrow>
#     </mrow>
#   </msub>
#   <mo>=</mo>
#   <msub>
#     <mo movablelimits="false">&#x2211;<!-- ∑ --></mo>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">j</mi>
#       </mrow>
#       <mo>&#x2A7D;<!-- ⩽ --></mo>
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">k</mi>
#       </mrow>
#     </mrow>
#   </msub>
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="fraktur">l</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">j</mi>
#       </mrow>
#     </mrow>
#   </msub>
# </math>
#
# The partitioned sampled lead matrices (corresponding to the sequence <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="fraktur">l</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="fraktur">l</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>2</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <msub>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="fraktur">l</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>3</mn>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <mo>&#x2026;<!-- … --></mo>
# </math>)
#  is
#
#  \begin{equation*}
# \bar{\mathrm{A}}^{\epsilon}(\mathrm{k})=\frac{1}{\mathrm{L}_{\mathrm{k}}}\sum\limits_{\mathfrak{j}\leqslant \mathrm{k}} \mathrm{A} (\gamma_{\mathrm{L}_{\mathfrak{j}-1},\mathrm{L}_{\mathfrak{j}}}^{\epsilon}),
# \end{equation*}
#
# The normalized sampled lead matices converge to the normalized lead matrix over one period.
#
# \begin{equation*}
# \overline{\mathrm{A}}^{\epsilon}(\mathrm{k})/\Vert\overline{\mathrm{A}}^{\epsilon}(\mathrm{k})\Vert\rightarrow \mathrm{A}^{\mathrm{p}}/\Vert \mathrm{A}^{\mathrm{p}}\Vert
# \end{equation*}

# %% [markdown]
# ## Chain of Offsets Model
#
# If the components of the trajectory γ are quintessentially equivalent processes, with co-rodinated internal clocks but run with a system of offsets. This is what would be expected in a system where internall subsystems cyclically exicted each other.
#
# Such a system would engender a collection of offsets (<math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>&#x03B1;<!-- α --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="fraktur">j</mi>
#       </mrow>
#     </mrow>
#   </msub>
#   <mo>&#x2208;<!-- ∈ --></mo>
#   <msup>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="double-struck">S</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#     </mrow>
#   </msup>
# </math>) and track the same underlying function ϕ so that:
#
# \begin{equation*}
# \mathrm{f}_{\mathrm{k}}(\mathrm{t})=a_{\mathrm{k}}\phi(\mathrm{t}-\alpha_{\mathrm{k}}),
# \end{equation*}
#
# with a noiseless trajectory of
#
# \begin{equation*}
# \gamma_{k}(\tau)=a_{k}\phi(\mathrm{R}(\tau)-\alpha_{k}), \mathrm{k}=1, \ldots, \mathrm{d}.
# \end{equation*}
#
# This will be the chain of offsets model (COOM). Under COOM we can discover the cyclic order of the functions/ <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>&#x03B1;<!-- α --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="fraktur">j</mi>
#       </mrow>
#     </mrow>
#   </msub>
#   <mo>,</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="fraktur">j</mi>
#   </mrow>
#   <mo>=</mo>
#   <mn>1</mn>
#   <mo>,</mo>
#   <mo>&#x2026;<!-- … --></mo>
#   <mo>,</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">d</mi>
#   </mrow>
# </math> from the trajectory γϵ
#
# First we compute the lead matrix under COOM:
#
# - Expand the Fourier series
#
# \begin{equation*}
# \phi(\top)=\sum\limits_{\mathrm{k}}\mathrm{c}_{\mathrm{k}}\exp(2\pi i\text{kT}).
# \end{equation*}
#
# - Then the lead matrix over period  <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msup>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="normal">A</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">p</mi>
#       </mrow>
#     </mrow>
#   </msup>
#   <mo>=</mo>
#   <mo stretchy="false">(</mo>
#   <msubsup>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi mathvariant="normal">A</mi>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">k</mi>
#       </mrow>
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="fraktur">l</mi>
#       </mrow>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="fraktur">p</mi>
#       </mrow>
#     </mrow>
#   </msubsup>
#   <msub>
#     <mo stretchy="false">)</mo>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mn>1</mn>
#       <mo>&#x2A7D;<!-- ⩽ --></mo>
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">k</mi>
#       </mrow>
#       <mo>,</mo>
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="fraktur">l</mi>
#       </mrow>
#       <mo>,</mo>
#       <mo>&#x2A7D;<!-- ⩽ --></mo>
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">d</mi>
#       </mrow>
#     </mrow>
#   </msub>
# </math>
#
# \begin{equation*}
# \mathrm{A}_{\text{kl}}^{\mathrm{p}}=2\pi a_{\mathrm{k}}a_{l}\sum\limits_{\mathrm{m}\geqslant 1}\mathrm{m}\vert \mathrm{c}_{\mathfrak{m}}\vert^{2}\sin(\mathrm{m}(\alpha_{\mathrm{k}}-\alpha_{l}))
# \end{equation*}
#
# ### Recovering the offsets
#
# Given the skew-symmetric matrix A approximating the lead matrix over one period Ap we can reconstruct the cyclic ordering of the offset phases <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msubsup>
#     <mi>&#x03B1;<!-- α --></mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mrow class="MJX-TeXAtom-ORD">
#         <mi mathvariant="normal">k</mi>
#       </mrow>
#     </mrow>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi class="MJX-variant" mathvariant="normal">&#x2032;<!-- ′ --></mi>
#     </mrow>
#   </msubsup>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">s</mi>
#   </mrow>
#   <mo>,</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">k</mi>
#   </mrow>
#   <mo>=</mo>
#   <mn>1</mn>
#   <mo>,</mo>
#   <mo>&#x2026;<!-- … --></mo>
#   <mo>,</mo>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mi mathvariant="normal">d</mi>
#   </mrow>
# </math> using two ways.
#
# These rely on the low rank approximations (if the matrix has dimensions m × n then it can be factorized into two matrices that have dimensions m×r and r ×n, basically a minimization solution). So if ϕ has just a single harmonic in its expansion then the skew symmetric matrix would have rank two. Spanned by the two rank one matricies A± with:
#
# \begin{equation*}
# \mathrm{A}_{\text{kl}}^{+}=a_{k}a_{l}\sin(\alpha_{\mathrm{k}})\cos(\alpha_{l})
# \end{equation*}
#
# and
#
# \begin{equation*}
# \mathrm{A}_{\text{kl}}^{-} =a_{k}a_{\mathrm{l}}\cos(\alpha_{\mathrm{k}})\sin(\alpha_{l}).
# \end{equation*}
#
# Even if ϕ has more than one mode, as long as the leading harmonic dominating ϕ that A is well approximated by the rank 2 matrix PAT (P = the projection on the 2-plane spanned by the eigenvectors corresponding to the largest in absolute value purely imaginary eigenvalues).
#
# Basically this is useful as the eigenvectors from the spectral decomposition of Ap and the arguments of the components of the first eigenvector would retain the cyclic order of the offsets

# %% [markdown]
# This is the equation for the lead lag matrix <math xmlns="http://www.w3.org/1998/Math/MathML"><mi xmlns="">A</mi><mo xmlns="">:=</mo><mfrac xmlns=""><mrow><mn>1</mn></mrow><mrow><mn>2</mn></mrow></mfrac><munderover xmlns=""><mrow><mo>∫</mo></mrow><mrow><mi>s</mi><mo>&lt;</mo><msub><mrow><mi>u</mi></mrow><mrow><mn>1</mn></mrow></msub><mo>&lt;</mo><msub><mrow><mi>u</mi></mrow><mrow><mn>2</mn></mrow></msub><mo>&lt;</mo><mi>t</mi></mrow><mrow></mrow></munderover><mi xmlns="">d</mi><msub xmlns=""><mrow><mi>X</mi></mrow><mrow><msub><mrow><mi>u</mi></mrow><mrow><mn>1</mn></mrow></msub></mrow></msub><mo xmlns="">⊗</mo><mi xmlns="">d</mi><msub xmlns=""><mrow><mi>X</mi></mrow><mrow><msub><mrow><mi>u</mi></mrow><mrow><mn>2</mn></mrow></msub></mrow></msub><mo xmlns="">−</mo><mi xmlns="">d</mi><msub xmlns=""><mrow><mi>X</mi></mrow><mrow><msub><mrow><mi>u</mi></mrow><mrow><mn>2</mn></mrow></msub></mrow></msub><mo xmlns="">⊗</mo><mi xmlns="">d</mi><msub xmlns=""><mrow><mi>X</mi></mrow><mrow><msub><mrow><mi>u</mi></mrow><mrow><mn>1</mn></mrow></msub></mrow></msub></math>
#
# which can also be expressed as: <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mtable displaystyle="true" columnalign="right left" columnspacing="0em" rowspacing="3pt">
#     <mtr>
#       <mtd>
#         <msub>
#           <mi>Q</mi>
#           <mrow data-mjx-texclass="ORD">
#             <mi>m</mi>
#             <mo>,</mo>
#             <mi>n</mi>
#           </mrow>
#         </msub>
#       </mtd>
#       <mtd>
#         <mi></mi>
#         <mo>=</mo>
#         <mfrac>
#           <mn>1</mn>
#           <mn>2</mn>
#         </mfrac>
#         <msub>
#           <mo data-mjx-texclass="OP">&#x222B;</mo>
#           <mi>I</mi>
#         </msub>
#         <mrow data-mjx-texclass="ORD">
#           <mi mathvariant="bold">x</mi>
#         </mrow>
#         <mo stretchy="false">(</mo>
#         <mi>t</mi>
#         <mo stretchy="false">)</mo>
#         <mtext>&#xA0;</mtext>
#         <msup>
#           <mrow data-mjx-texclass="INNER">
#             <mo data-mjx-texclass="OPEN">(</mo>
#             <msup>
#               <mrow data-mjx-texclass="ORD">
#                 <mi mathvariant="bold">x</mi>
#               </mrow>
#               <mo data-mjx-alternate="1">&#x2032;</mo>
#             </msup>
#             <mo stretchy="false">(</mo>
#             <mi>t</mi>
#             <mo stretchy="false">)</mo>
#             <mo data-mjx-texclass="CLOSE">)</mo>
#           </mrow>
#           <mi>T</mi>
#         </msup>
#         <mo>&#x2212;</mo>
#         <msup>
#           <mrow data-mjx-texclass="ORD">
#             <mi mathvariant="bold">x</mi>
#           </mrow>
#           <mo data-mjx-alternate="1">&#x2032;</mo>
#         </msup>
#         <mo stretchy="false">(</mo>
#         <mi>t</mi>
#         <mo stretchy="false">)</mo>
#         <mtext>&#xA0;</mtext>
#         <msup>
#           <mrow data-mjx-texclass="INNER">
#             <mo data-mjx-texclass="OPEN">(</mo>
#             <mrow data-mjx-texclass="ORD">
#               <mi mathvariant="bold">x</mi>
#             </mrow>
#             <mo stretchy="false">(</mo>
#             <mi>t</mi>
#             <mo stretchy="false">)</mo>
#             <mo data-mjx-texclass="CLOSE">)</mo>
#           </mrow>
#           <mi>T</mi>
#         </msup>
#         <mtext>&#xA0;</mtext>
#         <mi>d</mi>
#         <mi>t</mi>
#       </mtd>
#     </mtr>
#   </mtable>
# </math>

# %%
import pandas as pd
import numpy as np
from decouple import config
from fNeuro.utils.pickling import load_pickle
from fNeuro.connectivity.connectivity import Cyclic_analysis, get_mean_correlation_matrix, cyclic_order
from nilearn import datasets
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
from connectivity_measure import ConnectivityMeasure
from decouple import config
import os
import pandas as pd
import numpy as np
from fNeuro.utils.pickling import load_pickle

resting_path = config('resting')
time_series = load_pickle(os.path.join(resting_path, 'measures', 'time_series'))
an_time_series = list(time_series['an'].values())
hc_time_series = list(time_series['hc'].values())
group = np.asarray(hc_time_series + an_time_series)
participant_1 = group[0]


conn = ConnectivityMeasure(kind='cyclic', vectorize=False)
an_conn = conn.fit_transform(an_time_series)

# %%
X = an_time_series[0]

# Calculate the differences between the time series values.
diff = X[1:] - X[:-1]

# Calculate the quadratic covariation.
A = diff[1:] @ X[:-1].T

# Return the quadratic covariation.
t = 0.5 * (A - A.T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /data/project/BEACONB/resting/rsfMRI/attempting_to_build_cyclicity.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bdesktop.nan.kcl.ac.uk/data/project/BEACONB/resting/rsfMRI/attempting_to_build_cyclicity.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> A = diff[1:] @ X[:-1].T
#       <a href='vscode-notebook-cell://ssh-remote%2Bdesktop.nan.kcl.ac.uk/data/project/BEACONB/resting/rsfMRI/attempting_to_build_cyclicity.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # Return the quadratic covariation.
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bdesktop.nan.kcl.ac.uk/data/project/BEACONB/resting/rsfMRI/attempting_to_build_cyclicity.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> t = 0.5 * (A - A.T)
#
# ValueError: operands could not be broadcast together with shapes (190,191) (191,190)

# %%
from nilearn.connectome import ConnectivityMeasure
p_vec = ConnectivityMeasure(vectorize=True, kind='correlation', discard_diagonal=True)
l = p_vec.fit_transform(an_time_series)
# Out:
# /home/k1812017/.conda/envs/neuroimaging/lib/python3.10/site-packages/nilearn/connectome/connectivity_matrices.py:509: FutureWarning: The default strategy for standardize is currently 'zscore' which incorrectly uses population std to calculate sample zscores. The new strategy 'zscore_sample' corrects this behavior by using the sample std. In release 0.13, the default strategy will be replaced by the new strategy and the 'zscore' option will be removed. Please use 'zscore_sample' instead.
#   covariances_std = [
# ...

# %%
conn_vector = ConnectivityMeasure(vectorize=True, kind='precision', discard_diagonal=True)
p = conn.fit_transform(an_time_series)
p
# Out:
# array([[[  0.        ,  -0.83963396,  -7.79256842, ...,  -5.05495485,
#           16.52998989,  31.57064195],
#         [  0.83963396,   0.        , -28.65378227, ..., -35.77916286,
#            9.29753277,   5.64304122],
#         [  7.79256842,  28.65378227,   0.        , ..., -19.8689016 ,
#            8.83033049,  -8.19500618],
#         ...,
#         [  5.05495485,  35.77916286,  19.8689016 , ...,   0.        ,
#          -10.48110575,  31.694471  ],
#         [-16.52998989,  -9.29753277,  -8.83033049, ...,  10.48110575,
#            0.        , -20.5592379 ],
#         [-31.57064195,  -5.64304122,   8.19500618, ..., -31.694471  ,
#           20.5592379 ,   0.        ]],
#
#        [[  0.        , -11.77106783,   0.51311799, ...,  -6.2188141 ,
#            1.71216719,   1.74680171],
#         [ 11.77106783,   0.        ,  16.1458032 , ..., -16.451753  ,
#           14.03156971,   8.29371083],
#         [ -0.51311799, -16.1458032 ,   0.        , ..., -11.40280173,
# ...

# %%
from cyclicityanalysis import OrientedArea as oa

# %%
df = pd.DataFrame(an_time_series[0])

# %%
an = oa(df)
an.compute_lead_lag_df()
# Out:
#            0          1          2          3          4          5   \
# 0    0.000000  -0.839634  -7.792568 -15.258155  -8.239821   3.507780
# 1    0.839634   0.000000 -28.653782  20.979753  22.988132  21.191927
# 2    7.792568  28.653782   0.000000  -0.235291   0.985073   4.089503
# 3   15.258155 -20.979753   0.235291   0.000000 -35.162357 -45.911168
# 4    8.239821 -22.988132  -0.985073  35.162357   0.000000 -14.305380
# 5   -3.507780 -21.191927  -4.089503  45.911168  14.305380   0.000000
# 6   20.314412  -9.823588   5.995070  22.578772  -0.937001 -10.266133
# 7    6.524849   3.687412  14.613983  18.998199  20.836464  15.277003
# 8  -22.220130 -15.983130 -35.152704  11.300722   6.453424  11.378997
# 9   28.555397 -13.307049  -3.673005  12.669398  -5.182687  -7.743148
# 10  12.037653 -25.181983 -20.734350  32.316864   2.920878  -9.046905
# 11  52.647203   4.691521  -4.495455  -2.832684 -23.988161 -24.855487
# 12   1.294255  -3.542185  23.883668 -11.377204  -7.162381 -14.778780
# ...

# %%
def cylic_connectivity(data):
    
    '''
    Function to calculate the lead lag
    matrix for cyclic analysis. 

    my function


    '''

    X = pd.DataFrame(data, dtype='float64')
    diff = X.diff()
    A = X[:-1].T @ diff.values[1:]
    return np.array(0.5 * (A - A.T))

# %%
import cyclicityanalysis.orientedarea as cao

oriented_area = cao.OrientedArea(pd.DataFrame(participant_1))
lead_lag_df = oriented_area.compute_lead_lag_df()
lead_lag_df.values
# Out:
# array([[  0.        ,  -0.83963396,  -7.79256842, ...,  -5.05495485,
#          16.52998989,  31.57064195],
#        [  0.83963396,   0.        , -28.65378227, ..., -35.77916286,
#           9.29753277,   5.64304122],
#        [  7.79256842,  28.65378227,   0.        , ..., -19.8689016 ,
#           8.83033049,  -8.19500618],
#        ...,
#        [  5.05495485,  35.77916286,  19.8689016 , ...,   0.        ,
#         -10.48110575,  31.694471  ],
#        [-16.52998989,  -9.29753277,  -8.83033049, ...,  10.48110575,
#           0.        , -20.5592379 ],
#        [-31.57064195,  -5.64304122,   8.19500618, ..., -31.694471  ,
#          20.5592379 ,   0.        ]])

# %%
series = oriented_area.compute_pairwise_accumulated_oriented_area_df(0, 1)
# Out:
# /home/k1812017/.conda/envs/neuroimaging/lib/python3.10/site-packages/cyclicityanalysis/orientedarea.py:110: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pairwise_accumulated_oriented_area_df.fillna(method='ffill', inplace=True)

# %%
series
# Out:
#      0 - 1 Accumulated Oriented Area
# 0                           0.000000
# 1                          -0.015134
# 2                          -0.140200
# 3                          -0.528142
# 4                          -0.952747
# ..                               ...
# 187                        -0.007711
# 188                        -0.377813
# 189                        -0.736322
# 190                        -0.877964
# 191                        -0.839634
#
# [192 rows x 1 columns]

# %%
msdl = datasets.fetch_atlas_msdl()
individual_time_series = pd.DataFrame(data=participant_1, columns=msdl['labels'])
import cyclicityanalysis.orientedarea as cao

oriented_area = cao.OrientedArea(pd.DataFrame(participant_1))

# %%
connect = Cyclic_analysis(to_vectorize=False).fit(group)

# %%
import re
participant_order = load_pickle(os.path.join(resting_path, 'measures', 'connectome_participant_order'))
order = [re.findall('B\d\d\d\d', participant)[0] for participant in participant_order]

# %%
connectome_dictionary = dict(zip(order, connect))

# %%
z = list(map(pd.DataFrame, p.values()))

# %%
connect[0:65][0][1][1]
# Out:
# 0.0

# %%
import scipy.stats as stats

# %%
series_df = pd.concat((series, pd.DataFrame({'region_0': participant_1[:, 0], 'region_1': participant_1[:, 1]})))

# %%
plot = sns.lineplot(series)
plot.axhline(0.0, color="red", linestyle="--")
